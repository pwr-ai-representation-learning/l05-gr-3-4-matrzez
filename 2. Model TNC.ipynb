# %% [markdown]
# Przed oddaniem zadania upewnij się, że wszystko działa poprawnie.
# **Uruchom ponownie kernel** (z paska menu: Kernel$\rightarrow$Restart) a następnie
# **wykonaj wszystkie komórki** (z paska menu: Cell$\rightarrow$Run All).
#
# Upewnij się, że wypełniłeś wszystkie pola `TU WPISZ KOD` lub `TU WPISZ ODPOWIEDŹ`, oraz
# że podałeś swoje imię i nazwisko poniżej:

# %%
NAME = "Mateusz Rzeźnikiewicz"

# %% [markdown]
# ---

# %% [markdown]
# # 2. Model TNC
#
# Przedstawimy teraz zasadę działania modelu TNC, zaimplementujemy jego  najistotniejsze elementy oraz dokonamy ewaluacji modelu.

# %% [markdown]
# ## 2.1. Idea modelu TNC
# Dla ciągu czasowego $X \in \mathbb{R}^{D \times T}$ możemy określić okno przesuwne $X_{[t - \frac{\delta}{2}, t + \frac{\delta}{2}]}$ o długości $\delta$ wycentrowane wokół chwili $t$, które zawiera pomiary wszystkich cech w przedziale czasu $[t - \frac{\delta}{2}, t + \frac{\delta}{2}]$. Dla ułatwienia zapisu okno to będzie oznaczane jako $W_t$.
#
# Celem metody uczenia reprezentacji będzie uzyskanie wektorowej reprezentacji dowolnego okna $W_t$.

# %% [markdown]
# ### Temporalne sąsiedztwo
# Dla okna $W_t$ zdefiniujmy jego temporalne sąsiedztwo $N_t$ jako zbiór wszystkich okien wycentrowanych w $t^*$, gdzie wartość ta jest próbkowana z rozkładu normalnego $t^* \sim \mathcal{N}(t, \eta \cdot \delta)$. Parametr $\eta$ definiuje szerokość / zakres sąsiedztwa temporalnego.
#
# Wybór parametru $\eta$ może być oparty o wiedzę ekspercką, jednak w publikacji autorzy zaproponowali zastosowanie testu statystycznego **Augmented Dickey-Fuller (ADF)**, który będzie sprawdzać stacjonarność rozkładu próbek w sąsiedztwie temporalnym. Algorytm wyboru parametru zakłada, że rozpoczynamy od niewielkiej wartości, po czym iteracyjnie zwiększamy parametr $\eta$, powodując poszerzenie się temporalnego sąsiedztwa. Zwiększanie wartości następuje do momentu aż test statystyczny nie będzie w stanie odrzucić hipotezy zerowej.

# %% [markdown]
# ### "Uczenie kontrastowe"
# Okna w sąsiedztwie temporalnym możemy uznać jako podobne do obecnie rozważanego okna ciągu czasowego. Pozostaje zatem pytanie jak uzyskać przykłady negatywne, tak abyśmy mogli zastosować koncepcję uczenia kontrastowego.
#
# Moglibyśmy założyć, że wszystkie próbki (okna) poza temporalnym sąsiedztwem są przykładami negatywnymi. Może się jednak tak zdarzyć, że nawet bardzo odległe okno, jest w istocie podobne do obecnego (ma taką samą dynamikę zmian / pochodzi z tego samego rozkładu). W takiej sytuacji uczenie modelu nie byłoby efektywne. Autorzy proponują użycie podejścia **Positive-Unlabeled (PU) learning**, w którym mamy próbki bazowe, próbki pozytywne i próbki nieoznaczone. W naszym przykładzie próbkami nieoznaczonymi będą próbki spoza sąsiedztwa temporalnego.
#
# Do próbek nieoznaczonych są przypisywane wagi $w$ (tutaj: hiperparametr metody), a każda próbka nieoznaczona jest traktowana jako połączenie próbki pozytywnej z wagą $w$ oraz próbki negatywnej z wagą $1 - w$. Zobaczymy to dalej w funkcji kosztu.

# %% [markdown]
# ### Koder i dyskryminator
# Model TNC będziemy uczyć za pomocą funkcji kosztu, która pozwala odróżniać reprezentacje próbek z tego samego sąsiedztwa temporalnego od próbek spoza sąsiedztwa.
#
# Pierwszym elementem modelu TNC jest **koder** $\text{Enc}(W_t)$, które przekształca okno $W_t \in \mathbb{R}^{D \times \delta}$ w wektor reprezentacji $Z_t \in \mathbb{R}^M$.
#
# Drugim elementem jest **dyskryminator** $\mathcal{D}(Z_t, Z)$ pozwalający aproksymować prawdopodobieństwo tego, że $Z$ jest reprezentacją okna w sąsiedztwie $N_t$. Innymi słowy, dla dwóch wektorów reprezentacji zwraca prawdopodobieństwo tego, że te wektory (okna) należą do tego samego sąsiedztwa temporalnego.

# %% [markdown]
# Przeanalizujmy rysunek przedstawiający zasadę działania modelu TNC:
#
# ![](./assets/tnc.png)

# %% [markdown]
# ### Funkcja kosztu
# W najlepszym przypadku dyskryminator powinien zwracać wartości bliskie 1 dla reprezentacji z tego samego temporalnego sąsiedztwa oraz wartość 0 w przeciwnym przypadku. Funkcja kosztu jest zdefiniowana następująco:
#
# $$\mathcal{L} = -\mathbb{E}_{W_t\sim X}\left[ \mathbb{E}_{W_l \sim N_t}[\log \mathcal{D}(Z_t,Z_l)] +\mathbb{E}_{W_k \sim \bar{N}_t}[(1-w_t)\times \log(1 - \mathcal{D}(Z_t, Z_k)) + w_t\times \log\mathcal{D}(Z_t, Z_k)] \right]$$

# %% [markdown]
# ## 2.2. Implementacja kodera
# Ze względu na sekwencyjny charakter próbek w oknie, jako model kodera użyjemy dwukierunkowej sieci rekurencyjnego typu GRU, która na wyjściu cechy przekształci dodatkową warstwą liniową. Sieć rekurencyjna dostarcza nam stany ukryte w formie wektorów dla każdego punktu wejściowego w sekwencji, więc w celu otrzymania jednego wektora podsumowującego całą sekwencję należy dokonać odpowiedniej agregacji. W niniejszym koderze rozwarzymy dwie metody agregacji sekwencji stanów ukrytych:
# * wybór ostatniego stanu ukrytego
# * agregacja stanów ukrytych z wykorzystaniem mechanizmu uwagi (ang. _attention_)

# %% [markdown]
# ## Zadanie 2.1 (1.5 pkt)
# Zaimplementuj dwie klasy dla dwóch niżej zdefiniowanych stanów ukrytych:
#
# 1. `LastHiddenAggreagation` (0.5 pkt) - metoda `forward(...)` zwraca ostatni stan ukryty z sekwencji (pamiętaj, że jest to sieć dwukierunkowa, więc ostatnie stany ukryte dla każdego z kierunku będą na przeciwnych końcach hidden states)
# 2. `AttentionAggregation` (1 pkt):
#       * aplikuje [*scaled dot product attention*](https://arxiv.org/abs/1706.03762) oraz oblicza średnią z otrzymanych wektorów
#       * podpowiedź: możesz wykorzystać `torch.nn.MultiHeadAttention` z parametrem `num_heads=1`, ale **należy mieć zrozumienie i intuicje, jak działa mechanizm uwagi i jak może pomagać w agregacji**

# %%
import torch
from torch import nn, Tensor
import torch.nn.functional as F

class LastHiddenAggregation(nn.Module):
    def forward(self, rnn_output: Tensor) -> Tensor:
        """
        Aggregates information from sequence of vectors by taking last state.
        rnn_output: Tensor with dimensions [sequence_length, batch_size, hidden_dim]
        returns: Tensor with dimensions [batch_size, hidden_dim]
        """
        # TU WPISZ KOD
        return torch.cat([rnn_output[-1, :, :rnn_output.shape[-1] // 2],
                          rnn_output[0, :, rnn_output.shape[-1] // 2:]], dim=1)

class AttentionAggregation(nn.Module):
    def __init__(self, hidden_dim: int):
        super().__init__()
        # TU WPISZ KOD
        self.attention = nn.MultiheadAttention(
            embed_dim=hidden_dim,
            num_heads=1,
            batch_first=False,
        )

    def forward(self, rnn_output: Tensor) -> Tensor:
        """
        Aggregates information from sequence of vectors with scaled-dot-product attention.
        rnn_output: Tensor with dimensions [sequence_length, batch_size, hidden_dim]
        returns: Tensor with dimensions [batch_size, hidden_dim]
        """
        # TU WPISZ KOD
        attn_output, _ = self.attention(
            rnn_output,
            rnn_output,
            rnn_output,
        )

        return attn_output.mean(dim=0)

# %% [markdown]
# ## Zadanie 2.2 (1.5 pkt)
# Zaimplementuj klasę `GRUEncoder` zgodnie z poniższymi wymaganiami:
# - w metodzie `__init__()`:
#   * utwórz instancję sieci GRU o wymiarze wejściowym `in_dim`, wymiarze ukrytym `hidden_dim`, która posiada jedną warstwę oraz jest dwukierunkowa (ustaw dodatkowo parametr `batch_first=False`)
#   * utwórz instancję warstwy liniowej o odpowiednim wymiarze wejściowym oraz wyjściu o wymiarowości `emb_dim`
# - w metodzie `_get_initial_hidden()` utwórz wektor zer jako początkowy stan ukryty
# - w metodzie `forward()` przetwórz cechy okień podanych na wejściu i wyznacz wektory reprezentacji (używając sieci GRU a następnie warstwy liniowej)

# %%
from typing import Literal

class GRUEncoder(nn.Module):
    def __init__(
        self,
        agg: Literal["last", "attn"],
        in_dim: int,
        hidden_dim: int,
        emb_dim: int,
    ):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.emb_dim = emb_dim

        if agg == "last":
            self.agg = LastHiddenAggregation()
        elif agg == "attn":
            self.agg = AttentionAggregation(2 * hidden_dim)
        else:
            raise ValueError(f"Invalid aggregation name")

        # TU WPISZ KOD
        self.rnn = nn.GRU(
            input_size=in_dim,
            hidden_size=hidden_dim,
            num_layers=1,
            bidirectional=True,
            batch_first=False,
        )

        self.linear = nn.Linear(
            in_features=2 * hidden_dim,
            out_features=emb_dim,
        )

    def _get_initial_hidden(self, batch_size):
        # TU WPISZ KOD
        return torch.zeros(
            2,
            batch_size,
            self.hidden_dim,
        )

    def forward(self, x):
        x = x.permute(2, 0, 1)

        # TU WPISZ KOD
        h0 = self._get_initial_hidden(x.shape[1]).to(x.device)
        rnn_output, _ = self.rnn(x, h0)
        agg_output = self.agg(rnn_output)
        emb = self.linear(agg_output)

        return emb

# %% [markdown]
# ## 2.3. Implementacja dyskryminatora
# W przypadku dyskryminatora porównamy dwa proste modele, tak aby nie ryzykować przeuczeniem tego komponentu, tj. iloczyn skalarny i wielowarstwowy perceptron (MLP).

# %% [markdown]
# ## Zadanie 2.3 (2 pkt)
# Zaimplementuj 2 modele dyskryminatora zgodnie z następującymi wymaganiami:
#
# `DotProductDiscriminator` (1 pkt):
# - w metodzie `forward()` zwróc iloczyn skalarny odpowiadających sobie reprezentacji (uprzednio znormalizuj reprezentacje do jednostkowej długości)
#
# `MLPDiscriminator` (1 pkt):
# - w metodzie `__init__()` utwórz wielowarstwowy perceptron z następującymi warstwami (`d` to wymiar wejściowy):
#   * warstwa liniowa o rozmiarach 2*d na 4*d
#   * aktywacja ReLU
#   * dropout z prawdp. równym 0.5
#   * kolejna warstwa liniowa o rozmiarze 4*d na 1
# - w metodzie `forward()` dokonaj konkatenacji reprezentacji `z` oraz `z_tilde` a następnie przekaż je do perceptrona

# %%
class DotProductDiscriminator(nn.Module):
    def forward(self, z: Tensor, z_tilde: Tensor) -> Tensor:
        # TU WPISZ KOD
        z = F.normalize(z, p=2, dim=1)
        z_tilde = F.normalize(z_tilde, p=2, dim=1)
        return torch.sum(z * z_tilde, dim=1)


class MLPDiscriminator(nn.Module):
    def __init__(self, input_dim: int):
        super().__init__()

        # TU WPISZ KOD
        self.mlp = nn.Sequential(
            nn.Linear(2 * input_dim, 4 * input_dim),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4 * input_dim, 1),
        )

    def forward(self, z: Tensor, z_tilde: Tensor) -> Tensor:
        # TU WPISZ KOD
        p = self.mlp(torch.cat([z, z_tilde], dim=1))

        return p.view((-1,))

# %% [markdown]
# ## 2.4. Implementacja funkcji kosztu
# W celu implementacji funkcji kosztu możemy wspomóc się gotową funkcją binarnej entropii krzyżowej, zauważając że problem uczenia dyskryminatora (a zatem całego modelu TNC) sprowadza się do problemu klasyfikacji binarnej. **Należy zaimplementować funkcję kosztu w pełnej zgodności ze wzorem podanym w publikacji (i wspomnianym w niniejszym zeszycie)**

# %% [markdown]
# ## Zadanie 2.4 (3 pkt)
# Zaimplementuj moduł implementujący funkcję kosztu modelu TNC stosując następujące wskazówki/instrukcje:
# - `z_t` to reprezentacje obecnie rozważanych okien, `z_p` to reprezentacje pozytywne, natomiast `z_n` to reprezentacje nieoznaczone
# - najpierw wyznacz predykcje dyskryminatora dla pary `(z_t, z_p)` oraz `(z_t, z_n)`
# - przygotuj etykiety (zera i jedynki) dla par podobnych oraz różnych
# - oblicz funkcję binarnej entropii krzyżowej dla wyników dyskryminatora, pamiętaj, że:
#   * parę `(z_t, z_p)` chcemy traktować jako pozytywną (klasa 1)
#   * parę `(z_t, z_n)` chcemy traktować jako pozytywną z wagą `w` oraz jako negatywną (klasa 0) z wagą `1 - w`
# - zaimplementuj metodę `_compute_accuracy()`, która sprawdzi czy decyzje dyskryminatora są właściwe (pary pozytywne mają prawdp. `> 0.5`, a pary negatwne `< 0.5`; pamiętaj o zastosowaniu funkcji sigmoid!); wyniki uśrednij uzyskując miarę accuracy

# %%
from typing import Tuple

class TNCLossFunction(nn.Module):

    def __init__(
        self,
        discriminator: Literal["dot", "mlp"],
        emb_dim: int,
        w: float
    ):
        super().__init__()

        if discriminator == "dot":
            self.discriminator = DotProductDiscriminator()
        elif discriminator == "mlp":
            self.discriminator = MLPDiscriminator(input_dim=emb_dim)
        else:
            raise ValueError(f"Invalid discriminator: {discriminator}")

        self.bce = torch.nn.BCEWithLogitsLoss()
        self.w = w

    def forward(
        self,
        z_t: Tensor,
        z_p: Tensor,
        z_n: Tensor,
    ) -> Tuple[Tensor, float]:

        # TU WPISZ KOD
        d_p = self.discriminator(z_t, z_p)
        d_n = self.discriminator(z_t, z_n)

        y_p = torch.ones_like(d_p)
        y_n_positive = torch.ones_like(d_n)
        y_n_negative = torch.zeros_like(d_n)

        loss_p = self.bce(d_p, y_p)
        loss_n_positive = self.bce(d_n, y_n_positive)
        loss_n_negative = self.bce(d_n, y_n_negative)

        loss = (
            loss_p
            + self.w * loss_n_positive
            + (1 - self.w) * loss_n_negative
        )

        accuracy = self._compute_accuracy(d_p=d_p, d_n=d_n)

        return loss, accuracy

    @staticmethod
    def _compute_accuracy(d_p: Tensor, d_n: Tensor) -> float:
        # TU WPISZ KOD
        p_pos = torch.sigmoid(d_p)
        p_neg = torch.sigmoid(d_n)

        acc_p = (p_pos > 0.5).float()
        acc_n = (p_neg < 0.5).float()

        acc = torch.cat([acc_p, acc_n]).mean().item()

        return acc

# %% [markdown]
# ## 2.5. Uruchomienie modelu TNC
# Poniżej znajduje się kod pozwalający wyuczyć model TNC (implementacja w bibliotece PyTorch-Lightning). Ustawimy domyślny zbiór hiperparametrów i będziemy uczyć model przez 50 epok. Następnie zwizualizujemy otrzymane wektory reprezentacji i zastosujemy je w zadaniu klasyfikacji.

# %% [markdown]
# Moduł danych:

# %%
import os

import pytorch_lightning as pl
from torch.utils.data import DataLoader

from src.dataset import TNCDataset


class TrainDataModule(pl.LightningDataModule):

    def __init__(
        self,
        mc_sample_size: int,
        window_size: int,
        batch_size: int,
    ):
        super().__init__()

        self.mc_sample_size = mc_sample_size
        self.window_size = window_size
        self.batch_size = batch_size

        self.dataset = torch.load(f="./data/simulated.pt")

    def train_dataloader(self) -> DataLoader:
        return self._dataloader("x_train")

    def val_dataloader(self) -> DataLoader:
        return self._dataloader("x_val", shuffle=False)

    def _dataloader(self, split: str, shuffle: bool = True) -> DataLoader:
        data = TNCDataset(
            x=self.dataset[split],
            mc_sample_size=self.mc_sample_size,
            window_size=self.window_size,
        )
        return DataLoader(
            data,
            batch_size=self.batch_size,
            shuffle=shuffle,
            num_workers=int(os.environ.get("NUM_WORKERS", 0)),
        )

# %% [markdown]
# Model TNC:

# %%
import numpy as np
from typing import Any

class TNCModel(pl.LightningModule):

    def __init__(self, hparams: dict[str, Any]):
        super().__init__()

        self.save_hyperparameters(hparams)

        self.encoder = GRUEncoder(
            agg=hparams["agg"],
            in_dim=hparams["in_dim"],
            hidden_dim=hparams["hidden_dim"],
            emb_dim=hparams["emb_dim"],
        )
        self._loss_fn = TNCLossFunction(
            discriminator=hparams["discriminator"],
            emb_dim=self.encoder.emb_dim,
            w=self.hparams["w"],
        )

        self.training_step_outputs = []
        self.validation_step_outputs = []
        
    def forward(self, x):
        return self.encoder(x)

    def training_step(self, batch, batch_idx):
        loss, acc = self._common_step(batch)
        return {"loss": loss, "acc": acc}

    def validation_step(self, batch, batch_idx):
        loss, acc = self._common_step(batch)
        return {"loss": loss, "acc": acc}

    def on_train_batch_end(self, outputs, batch, batch_idx) -> None:
        self.training_step_outputs.append(outputs)

    def on_validation_batch_end(self, outputs, batch, batch_idx) -> None:
        self.validation_step_outputs.append(outputs)
         
    def on_validation_epoch_start(self):
        avg_loss, avg_accs = self._summarize_outputs(self.training_step_outputs)
        self.training_step_outputs = []
        
        self.log("step", self.trainer.current_epoch)
        self.log("train/loss", avg_loss, on_epoch=True, on_step=False)
        self.log("train/acc", avg_accs, on_epoch=True, on_step=False)

    def on_validation_epoch_end(self):
        avg_loss, avg_accs = self._summarize_outputs(self.validation_step_outputs)
        self.validation_step_outputs = []
        
        self.log("step", self.trainer.current_epoch)
        self.log("val/loss", avg_loss, on_epoch=True, on_step=False)
        self.log("val/acc", avg_accs, on_epoch=True, on_step=False)

    def _common_step(self, batch):
        x_t, x_p, x_n, _ = batch
        mc_sample = x_p.shape[1]
        batch_size, f_size, len_size = x_t.shape

        x_p = x_p.reshape((-1, f_size, len_size))
        x_n = x_n.reshape((-1, f_size, len_size))
        x_t = x_t.repeat(mc_sample, 1, 1)

        z_t = self.encoder(x_t)
        z_p = self.encoder(x_p)
        z_n = self.encoder(x_n)

        loss, acc = self._loss_fn(z_t=z_t, z_p=z_p, z_n=z_n)

        return loss, acc

    def configure_optimizers(self):
        return torch.optim.AdamW(
            self.parameters(),
            lr=self.hparams["lr"],
            weight_decay=self.hparams["weight_decay"],
        )
        
    @staticmethod
    def _summarize_outputs(outputs):
        losses = [out["loss"].item() for out in outputs]
        accs = [out["acc"] for out in outputs]

        avg_loss = np.mean(losses)
        avg_accs = np.mean(accs)

        return avg_loss, avg_accs

# %% [markdown]
# Ustawienie domyślnych hiperparametrów:

# %%
default_hparams = {
    "agg": "last",
    "discriminator": "dot",
    "in_dim": 3,
    "hidden_dim": 100,
    "emb_dim": 10,
    "window_size": 50,
    "mc_sample_size": 40,
    "w": 0.05,
    "num_epochs": 50,
    "lr": 1e-3,
    "weight_decay": 1e-3,
    "batch_size": 10,
    "name": "default",
}

# %% [markdown]
# Uczenie modelu TNC:

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./data/logs --port 6006
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# Traceback (most recent call last):
#   File "/usr/local/bin/tensorboard", line 3, in <module>
#     from tensorboard.main import run_main
#   File "/usr/local/lib/python3.12/site-packages/tensorboard/main.py", line 27, in <module>
#     from tensorboard import default
#   File "/usr/local/lib/python3.12/site-packages/tensorboard/default.py", line 30, in <module>
#     import pkg_resources
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
datamodule = TrainDataModule(
        mc_sample_size=default_hparams["mc_sample_size"],
        window_size=default_hparams["window_size"],
        batch_size=default_hparams["batch_size"],
)
datamodule.setup("train")

# %%
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger


def train(hparams):
    pl.seed_everything(42)

    datamodule = TrainDataModule(
        mc_sample_size=hparams["mc_sample_size"],
        window_size=hparams["window_size"],
        batch_size=hparams["batch_size"],
    )
    tnc = TNCModel(hparams)

    model_chkpt = ModelCheckpoint(
        dirpath=f"./data/checkpoints/{hparams['name']}/",
        filename="model",
        monitor="val/acc",
        mode="max",
        verbose=False,
    )
    trainer = pl.Trainer(
        logger=TensorBoardLogger(
            save_dir="./data/logs",
            name=f"TNC_{hparams['name']}",
            default_hp_metric=False,
        ),
        callbacks=[model_chkpt],
        num_sanity_val_steps=0,
        log_every_n_steps=1,
        max_epochs=hparams["num_epochs"],
        accelerator="cpu", # change to "cuda", if want to train on GPU
    )

    trainer.fit(model=tnc, datamodule=datamodule)
    
    
train(hparams=default_hparams)
# Out:
# Seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 65.0 K | train | 0
# 1 | _loss_fn | TNCLossFunction | 0      | train | 0
# -------------------------------------------------------------
# 65.0 K    Trainable params
# 0         Non-trainable params
# 65.0 K    Total params
# 0.260     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 7/7 [00:55<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.02it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.32it/s]
# Epoch 1: 100%|██████████| 7/7 [00:10<00:00,  0.67it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.49it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.60it/s]
# Epoch 2: 100%|██████████| 7/7 [00:09<00:00,  0.74it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.10it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.92it/s]
# Epoch 3: 100%|██████████| 7/7 [00:11<00:00,  0.61it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.63it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.77it/s]
# Epoch 4: 100%|██████████| 7/7 [00:39<00:00,  0.18it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.53it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.51it/s]
# Epoch 5: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.89it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.99it/s]
# Epoch 6: 100%|██████████| 7/7 [00:08<00:00,  0.80it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.70it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.80it/s]
# Epoch 7: 100%|██████████| 7/7 [00:11<00:00,  0.62it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.94it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.42it/s]
# Epoch 8: 100%|██████████| 7/7 [00:12<00:00,  0.54it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.22it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.91it/s]
# Epoch 9: 100%|██████████| 7/7 [00:33<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.75it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Epoch 10: 100%|██████████| 7/7 [00:10<00:00,  0.68it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.14it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.57it/s]
# Epoch 11: 100%|██████████| 7/7 [00:10<00:00,  0.67it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.42it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.68it/s]
# Epoch 12: 100%|██████████| 7/7 [00:09<00:00,  0.74it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.20it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.34it/s]
# Epoch 13: 100%|██████████| 7/7 [00:08<00:00,  0.80it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.12it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.92it/s]
# Epoch 14: 100%|██████████| 7/7 [00:15<00:00,  0.44it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.04it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.13it/s]
# Epoch 15: 100%|██████████| 7/7 [00:21<00:00,  0.32it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.54it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.53it/s]
# Epoch 16: 100%|██████████| 7/7 [00:13<00:00,  0.51it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.62it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.73it/s]
# Epoch 17: 100%|██████████| 7/7 [00:08<00:00,  0.81it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.79it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.91it/s]
# Epoch 18: 100%|██████████| 7/7 [00:07<00:00,  0.91it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.18it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.09it/s]
# Epoch 19: 100%|██████████| 7/7 [00:07<00:00,  0.98it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.71it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.90it/s]
# Epoch 20: 100%|██████████| 7/7 [00:07<00:00,  0.99it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.43it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.18it/s]
# Epoch 21: 100%|██████████| 7/7 [00:06<00:00,  1.02it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.46it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.92it/s]
# Epoch 22: 100%|██████████| 7/7 [00:06<00:00,  1.06it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.26it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s]
# Epoch 23: 100%|██████████| 7/7 [00:20<00:00,  0.34it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.70it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.53it/s]
# Epoch 24: 100%|██████████| 7/7 [00:29<00:00,  0.24it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.41it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.61it/s]
# Epoch 25: 100%|██████████| 7/7 [00:09<00:00,  0.77it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.06it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.78it/s]
# Epoch 26: 100%|██████████| 7/7 [00:10<00:00,  0.65it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.84it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.32it/s]
# Epoch 27: 100%|██████████| 7/7 [00:08<00:00,  0.80it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.59it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.50it/s]
# Epoch 28: 100%|██████████| 7/7 [00:09<00:00,  0.76it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.68it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.93it/s]
# Epoch 29: 100%|██████████| 7/7 [00:13<00:00,  0.53it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.86it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# Epoch 30: 100%|██████████| 7/7 [00:41<00:00,  0.17it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.06it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.34it/s]
# Epoch 31: 100%|██████████| 7/7 [00:10<00:00,  0.69it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.78it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.98it/s]
# Epoch 32: 100%|██████████| 7/7 [00:08<00:00,  0.81it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.20it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.28it/s]
# Epoch 33: 100%|██████████| 7/7 [00:07<00:00,  0.98it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.83it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.19it/s]
# Epoch 34: 100%|██████████| 7/7 [00:07<00:00,  0.89it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.89it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.70it/s]
# Epoch 35: 100%|██████████| 7/7 [00:09<00:00,  0.71it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.63it/s]
# Epoch 36: 100%|██████████| 7/7 [00:09<00:00,  0.75it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.09it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
# Epoch 37: 100%|██████████| 7/7 [00:13<00:00,  0.53it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.73it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.55it/s]
# Epoch 38: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.65it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.39it/s]
# Epoch 39: 100%|██████████| 7/7 [00:09<00:00,  0.73it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.22it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.67it/s]
# Epoch 40: 100%|██████████| 7/7 [00:07<00:00,  0.92it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.75it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.13it/s]
# Epoch 41: 100%|██████████| 7/7 [00:06<00:00,  1.02it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.63it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.25it/s]
# Epoch 42: 100%|██████████| 7/7 [00:07<00:00,  0.96it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.00it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.67it/s]
# Epoch 43: 100%|██████████| 7/7 [00:10<00:00,  0.69it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.90it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.78it/s]
# Epoch 44: 100%|██████████| 7/7 [00:14<00:00,  0.49it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.60it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.81it/s]
# Epoch 45: 100%|██████████| 7/7 [00:30<00:00,  0.23it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.86it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Epoch 46: 100%|██████████| 7/7 [00:12<00:00,  0.57it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.80it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.93it/s]
# Epoch 47: 100%|██████████| 7/7 [00:08<00:00,  0.80it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.42it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.86it/s]
# Epoch 48: 100%|██████████| 7/7 [00:09<00:00,  0.78it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.20it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.60it/s]
# Epoch 49: 100%|██████████| 7/7 [00:08<00:00,  0.82it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.78it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.02it/s]
# Epoch 49: 100%|██████████| 7/7 [00:09<00:00,  0.71it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|██████████| 7/7 [00:09<00:00,  0.71it/s, v_num=0]

# %% [markdown]
# Ewaluacja modelu:
# - wizualizacja wektorów ukrytych i surowych danych
# - zadanie klasyfikacji stanu procesu generującego ciąg czasowy
# - zadanie klasteryzacji wektorów reprezentacji

# %%
from src.utils import visualize_embeddings
from src.evaluations import evaluate_model


def visualize(name: str):
    best_tnc_model = TNCModel.load_from_checkpoint(
        checkpoint_path=f"./data/checkpoints/{name}/model.ckpt"
    )

    best_encoder = best_tnc_model.encoder

    dataset = torch.load("./data/simulated.pt")

    fig = visualize_embeddings(
        x_all=dataset["x_all"],
        y_all=dataset["y_all"],
        encoder=best_encoder,
        window_size=best_tnc_model.hparams["window_size"],
    )
    return fig


visualize(default_hparams["name"])

# %%
def evaluate_classification_clustering(name: str):
    best_tnc_model = TNCModel.load_from_checkpoint(
        checkpoint_path=f"./data/checkpoints/{name}/model.ckpt"
    )

    best_encoder = best_tnc_model.encoder

    dataset = torch.load("./data/simulated.pt")
    
    metrics = evaluate_model(
        dataset=dataset,
        encoder=best_encoder,
        window_size=best_tnc_model.hparams["window_size"],
    )
    
    return metrics


evaluate_classification_clustering(default_hparams["name"])
# Out:
# {'auc': {'train': np.float64(0.8990239624841788),
#   'val': np.float64(0.8807897932929757),
#   'test': np.float64(0.8882407590779222)},
#  'cluster': {'silhouette': np.float32(0.2110828),
#   'davies_bouldin': np.float64(1.5852441070476493)}}

# %% [markdown]
# ## Zadanie 2.5. Badanie wpływu metody agregacji oraz dyskryminatora TNC (1.5 pkt)
# Korzystając z domyślnych hiperparametrów sprawdź, który z zaimplementowanych modułów agregacji oraz dyskryminatora dostarcza najlepszych rezultatów. Sprawdź wszystkie 4 kombinacje $\{\mathrm{last}, \mathrm{attn}\} \times \{\mathrm{dot}, \mathrm{mlp}\}$

# %%
import pandas as pd

results = []

for agg in ["last", "attn"]:
    for disc in ["dot", "mlp"]:
        print("\n" + "="*50)
        print(f"Agregacja: {agg} | Dyskryminator: {disc}")
        print("="*50)

        params = default_hparams.copy()
        params["agg"] = agg
        params["discriminator"] = disc
        params["name"] = f"{agg}_{disc}"

        train(params)

        metrics = evaluate_classification_clustering(params["name"])

        results.append({
            "agg": agg,
            "disc": disc,
            "auc_test": metrics["auc"]["test"],
            "silhouette": metrics["cluster"]["silhouette"],
            "davies_bouldin": metrics["cluster"]["davies_bouldin"]
        })

df = pd.DataFrame(results)
df
# Out:
# Seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 65.0 K | train | 0
# 1 | _loss_fn | TNCLossFunction | 0      | train | 0
# -------------------------------------------------------------
# 65.0 K    Trainable params
# 0         Non-trainable params
# 65.0 K    Total params
# 0.260     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# ==================================================
# Agregacja: last | Dyskryminator: dot
# ==================================================
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 7/7 [00:13<00:00,  0.52it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.17it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.80it/s]
# Epoch 1: 100%|██████████| 7/7 [00:33<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.75it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.82it/s]
# Epoch 2: 100%|██████████| 7/7 [00:09<00:00,  0.75it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.04it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.97it/s]
# Epoch 3: 100%|██████████| 7/7 [00:09<00:00,  0.72it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.90it/s]
# Epoch 4: 100%|██████████| 7/7 [00:09<00:00,  0.73it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.03it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.44it/s]
# Epoch 5: 100%|██████████| 7/7 [00:13<00:00,  0.50it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.40it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.18it/s]
# Epoch 6: 100%|██████████| 7/7 [00:32<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.83it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.70it/s]
# Epoch 7: 100%|██████████| 7/7 [00:11<00:00,  0.61it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.51it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.41it/s]
# Epoch 8: 100%|██████████| 7/7 [00:12<00:00,  0.54it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.30it/s]
# Epoch 9: 100%|██████████| 7/7 [00:07<00:00,  0.88it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.10it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.88it/s]
# Epoch 10: 100%|██████████| 7/7 [00:06<00:00,  1.04it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.66it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.12it/s]
# Epoch 11: 100%|██████████| 7/7 [00:13<00:00,  0.53it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.49it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.26it/s]
# Epoch 12: 100%|██████████| 7/7 [00:19<00:00,  0.35it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.79it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.63it/s]
# Epoch 13: 100%|██████████| 7/7 [00:13<00:00,  0.52it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.03it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.83it/s]
# Epoch 14: 100%|██████████| 7/7 [00:11<00:00,  0.62it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.90it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.03it/s]
# Epoch 15: 100%|██████████| 7/7 [00:07<00:00,  0.91it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.10it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.33it/s]
# Epoch 16: 100%|██████████| 7/7 [00:07<00:00,  1.00it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.02it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.30it/s]
# Epoch 17: 100%|██████████| 7/7 [00:07<00:00,  0.93it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.83it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.13it/s]
# Epoch 18: 100%|██████████| 7/7 [00:07<00:00,  0.99it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.78it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.37it/s]
# Epoch 19: 100%|██████████| 7/7 [00:06<00:00,  1.07it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.72it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.78it/s]
# Epoch 20: 100%|██████████| 7/7 [00:20<00:00,  0.35it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.45it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.84it/s]
# Epoch 21: 100%|██████████| 7/7 [00:32<00:00,  0.22it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.63it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Epoch 22: 100%|██████████| 7/7 [00:27<00:00,  0.26it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.79it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.97it/s]
# Epoch 23: 100%|██████████| 7/7 [00:10<00:00,  0.65it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.90it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.27it/s]
# Epoch 24: 100%|██████████| 7/7 [00:16<00:00,  0.41it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.95it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.39it/s]
# Epoch 25: 100%|██████████| 7/7 [01:01<00:00,  0.11it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.39it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.72it/s]
# Epoch 26: 100%|██████████| 7/7 [00:10<00:00,  0.65it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.88it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.09it/s]
# Epoch 27: 100%|██████████| 7/7 [00:09<00:00,  0.76it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.01it/s]
# Epoch 28: 100%|██████████| 7/7 [00:45<00:00,  0.15it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.71it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.71it/s]
# Epoch 29: 100%|██████████| 7/7 [00:31<00:00,  0.22it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.34it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.03it/s]
# Epoch 30: 100%|██████████| 7/7 [00:08<00:00,  0.80it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.38it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.17it/s]
# Epoch 31: 100%|██████████| 7/7 [00:07<00:00,  0.97it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.38it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.24it/s]
# Epoch 32: 100%|██████████| 7/7 [00:07<00:00,  0.96it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.76it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.41it/s]
# Epoch 33: 100%|██████████| 7/7 [00:09<00:00,  0.70it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.88it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.08it/s]
# Epoch 34: 100%|██████████| 7/7 [00:13<00:00,  0.52it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.18it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Epoch 35: 100%|██████████| 7/7 [00:36<00:00,  0.19it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.93it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.66it/s]
# Epoch 36: 100%|██████████| 7/7 [00:15<00:00,  0.44it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.32it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.33it/s]
# Epoch 37: 100%|██████████| 7/7 [00:09<00:00,  0.75it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.83it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.80it/s]
# Epoch 38: 100%|██████████| 7/7 [00:08<00:00,  0.83it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.68it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.69it/s]
# Epoch 39: 100%|██████████| 7/7 [00:13<00:00,  0.52it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.64it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.31it/s]
# Epoch 40: 100%|██████████| 7/7 [01:11<00:00,  0.10it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.97it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Epoch 41: 100%|██████████| 7/7 [00:09<00:00,  0.71it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.75it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.72it/s]
# Epoch 42: 100%|██████████| 7/7 [00:12<00:00,  0.57it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.71it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.73it/s]
# Epoch 43: 100%|██████████| 7/7 [00:57<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:17<00:17,  0.06it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:18<00:00,  0.11it/s]
# Epoch 44: 100%|██████████| 7/7 [00:11<00:00,  0.59it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.99it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.96it/s]
# Epoch 45: 100%|██████████| 7/7 [00:51<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.55it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:05<00:00,  0.38it/s]
# Epoch 46: 100%|██████████| 7/7 [00:45<00:00,  0.15it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.34it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.65it/s]
# Epoch 47: 100%|██████████| 7/7 [00:12<00:00,  0.58it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.97it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.83it/s]
# Epoch 48: 100%|██████████| 7/7 [00:10<00:00,  0.69it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.89it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.31it/s]
# Epoch 49: 100%|██████████| 7/7 [00:13<00:00,  0.51it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.48it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.88it/s]
# Epoch 49: 100%|██████████| 7/7 [00:18<00:00,  0.38it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|██████████| 7/7 [00:18<00:00,  0.38it/s, v_num=0]
# Seed set to 42
# ==================================================
# Agregacja: last | Dyskryminator: mlp
# ==================================================
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 65.0 K | train | 0
# 1 | _loss_fn | TNCLossFunction | 881    | train | 0
# -------------------------------------------------------------
# 65.9 K    Trainable params
# 0         Non-trainable params
# 65.9 K    Total params
# 0.264     Total estimated model params size (MB)
# 12        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 7/7 [00:42<00:00,  0.17it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.36it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.41it/s]
# Epoch 1: 100%|██████████| 7/7 [00:23<00:00,  0.30it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.20it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.22it/s]
# Epoch 2: 100%|██████████| 7/7 [00:09<00:00,  0.74it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.60it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.12it/s]
# Epoch 3: 100%|██████████| 7/7 [00:12<00:00,  0.58it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# Epoch 4: 100%|██████████| 7/7 [00:32<00:00,  0.22it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:03<00:03,  0.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:07<00:00,  0.28it/s]
# Epoch 5: 100%|██████████| 7/7 [00:30<00:00,  0.23it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.50it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.55it/s]
# Epoch 6: 100%|██████████| 7/7 [00:09<00:00,  0.74it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.03it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.20it/s]
# Epoch 7: 100%|██████████| 7/7 [00:08<00:00,  0.80it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.89it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.29it/s]
# Epoch 8: 100%|██████████| 7/7 [00:14<00:00,  0.50it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.70it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.43it/s]
# Epoch 9: 100%|██████████| 7/7 [00:13<00:00,  0.50it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.11it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.48it/s]
# Epoch 10: 100%|██████████| 7/7 [00:38<00:00,  0.18it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.78it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.64it/s]
# Epoch 11: 100%|██████████| 7/7 [00:08<00:00,  0.87it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.06it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.16it/s]
# Epoch 12: 100%|██████████| 7/7 [00:08<00:00,  0.82it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.57it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.40it/s]
# Epoch 13: 100%|██████████| 7/7 [00:10<00:00,  0.65it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.80it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.37it/s]
# Epoch 14: 100%|██████████| 7/7 [00:13<00:00,  0.52it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.95it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.74it/s]
# Epoch 15: 100%|██████████| 7/7 [00:38<00:00,  0.18it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.44it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.74it/s]
# Epoch 16: 100%|██████████| 7/7 [00:12<00:00,  0.56it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.92it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.81it/s]
# Epoch 17: 100%|██████████| 7/7 [00:09<00:00,  0.75it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.02it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.06it/s]
# Epoch 18: 100%|██████████| 7/7 [00:10<00:00,  0.64it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.13it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
# Epoch 19: 100%|██████████| 7/7 [00:49<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.40it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.61it/s]
# Epoch 20: 100%|██████████| 7/7 [00:44<00:00,  0.16it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.68it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.92it/s]
# Epoch 21: 100%|██████████| 7/7 [00:12<00:00,  0.58it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.89it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Epoch 22: 100%|██████████| 7/7 [00:49<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:03<00:03,  0.26it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:07<00:00,  0.27it/s]
# Epoch 23: 100%|██████████| 7/7 [00:28<00:00,  0.25it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.87it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.16it/s]
# Epoch 24: 100%|██████████| 7/7 [00:07<00:00,  0.90it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.86it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.66it/s]
# Epoch 25: 100%|██████████| 7/7 [00:10<00:00,  0.70it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.31it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.63it/s]
# Epoch 26: 100%|██████████| 7/7 [00:15<00:00,  0.44it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.15it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.76it/s]
# Epoch 27: 100%|██████████| 7/7 [00:35<00:00,  0.20it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.50it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.85it/s]
# Epoch 28: 100%|██████████| 7/7 [00:21<00:00,  0.33it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.52it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.93it/s]
# Epoch 29: 100%|██████████| 7/7 [00:08<00:00,  0.83it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.68it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.47it/s]
# Epoch 30: 100%|██████████| 7/7 [00:08<00:00,  0.82it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.09it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.41it/s]
# Epoch 31: 100%|██████████| 7/7 [00:11<00:00,  0.63it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.35it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.78it/s]
# Epoch 32: 100%|██████████| 7/7 [00:22<00:00,  0.31it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:05<00:05,  0.18it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:07<00:00,  0.26it/s]
# Epoch 33: 100%|██████████| 7/7 [00:36<00:00,  0.19it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.93it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.36it/s]
# Epoch 34: 100%|██████████| 7/7 [00:10<00:00,  0.68it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.96it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.75it/s]
# Epoch 35: 100%|██████████| 7/7 [00:08<00:00,  0.80it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.22it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.09it/s]
# Epoch 36: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.50it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]
# Epoch 37: 100%|██████████| 7/7 [00:50<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:09<00:09,  0.10it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:13<00:00,  0.14it/s]
# Epoch 38: 100%|██████████| 7/7 [00:28<00:00,  0.24it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.00it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
# Epoch 39: 100%|██████████| 7/7 [00:09<00:00,  0.73it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.16it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.41it/s]
# Epoch 40: 100%|██████████| 7/7 [00:18<00:00,  0.38it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.56it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.46it/s]
# Epoch 41: 100%|██████████| 7/7 [00:37<00:00,  0.19it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.97it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.67it/s]
# Epoch 42: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.07it/s]
# Epoch 43: 100%|██████████| 7/7 [00:08<00:00,  0.81it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  3.16it/s]
# Epoch 44: 100%|██████████| 7/7 [00:08<00:00,  0.85it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.87it/s]
# Epoch 45: 100%|██████████| 7/7 [00:08<00:00,  0.83it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  5.18it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.96it/s]
# Epoch 46: 100%|██████████| 7/7 [00:13<00:00,  0.53it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.34it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:05<00:00,  0.38it/s]
# Epoch 47: 100%|██████████| 7/7 [00:37<00:00,  0.18it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.64it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.76it/s]
# Epoch 48: 100%|██████████| 7/7 [00:36<00:00,  0.19it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.78it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.11it/s]
# Epoch 49: 100%|██████████| 7/7 [00:10<00:00,  0.64it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.18it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.63it/s]
# Epoch 49: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|██████████| 7/7 [00:15<00:00,  0.44it/s, v_num=0]
# Seed set to 42
# ==================================================
# Agregacja: attn | Dyskryminator: dot
# ==================================================
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 225 K  | train | 0
# 1 | _loss_fn | TNCLossFunction | 0      | train | 0
# -------------------------------------------------------------
# 225 K     Trainable params
# 0         Non-trainable params
# 225 K     Total params
# 0.903     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 7/7 [01:22<00:00,  0.08it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.46it/s]
# Epoch 1: 100%|██████████| 7/7 [01:30<00:00,  0.08it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.45it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.42it/s]
# Epoch 2: 100%|██████████| 7/7 [00:59<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.72it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.63it/s]
# Epoch 3: 100%|██████████| 7/7 [00:58<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.09it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.64it/s]
# Epoch 4: 100%|██████████| 7/7 [00:30<00:00,  0.23it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.56it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.11it/s]
# Epoch 5: 100%|██████████| 7/7 [00:14<00:00,  0.50it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.42it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.56it/s]
# Epoch 6: 100%|██████████| 7/7 [00:28<00:00,  0.25it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.03it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.62it/s]
# Epoch 7: 100%|██████████| 7/7 [00:52<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.02it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.42it/s]
# Epoch 8: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.71it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s]
# Epoch 9: 100%|██████████| 7/7 [00:52<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:11<00:11,  0.08it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:15<00:00,  0.13it/s]
# Epoch 10: 100%|██████████| 7/7 [02:11<00:00,  0.05it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.54it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.48it/s]
# Epoch 11: 100%|██████████| 7/7 [00:42<00:00,  0.17it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.03it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.62it/s]
# Epoch 12: 100%|██████████| 7/7 [00:29<00:00,  0.24it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.61it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.57it/s]
# Epoch 13: 100%|██████████| 7/7 [00:53<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.96it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.59it/s]
# Epoch 14: 100%|██████████| 7/7 [00:45<00:00,  0.16it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.59it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.57it/s]
# Epoch 15: 100%|██████████| 7/7 [00:15<00:00,  0.46it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.69it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.56it/s]
# Epoch 16: 100%|██████████| 7/7 [00:16<00:00,  0.43it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# ...
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.66it/s]
# Epoch 8: 100%|██████████| 7/7 [00:18<00:00,  0.38it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.97it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.38it/s]
# Epoch 9: 100%|██████████| 7/7 [01:01<00:00,  0.11it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:05<00:05,  0.18it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:08<00:00,  0.22it/s]
# Epoch 10: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.65it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.58it/s]
# Epoch 11: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.47it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.44it/s]
# Epoch 12: 100%|██████████| 7/7 [00:32<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.07it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.73it/s]
# Epoch 13: 100%|██████████| 7/7 [00:34<00:00,  0.20it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.30it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.72it/s]
# Epoch 14: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.35it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.36it/s]
# Epoch 15: 100%|██████████| 7/7 [00:35<00:00,  0.20it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:06<00:06,  0.16it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:13<00:00,  0.15it/s]
# Epoch 16: 100%|██████████| 7/7 [00:42<00:00,  0.17it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.26it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.76it/s]
# Epoch 17: 100%|██████████| 7/7 [00:21<00:00,  0.32it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.84it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.63it/s]
# Epoch 18: 100%|██████████| 7/7 [01:03<00:00,  0.11it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.55it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Epoch 19: 100%|██████████| 7/7 [00:23<00:00,  0.29it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.30it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.95it/s]
# Epoch 20: 100%|██████████| 7/7 [00:52<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.55it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.73it/s]
# Epoch 21: 100%|██████████| 7/7 [00:19<00:00,  0.37it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.35it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.87it/s]
# Epoch 22: 100%|██████████| 7/7 [00:42<00:00,  0.16it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.48it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.51it/s]
# Epoch 23: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.43it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s]
# Epoch 24: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.71it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# Epoch 25: 100%|██████████| 7/7 [00:41<00:00,  0.17it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.33it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.78it/s]
# Epoch 26: 100%|██████████| 7/7 [00:16<00:00,  0.43it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.90it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.37it/s]
# Epoch 27: 100%|██████████| 7/7 [00:35<00:00,  0.20it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.34it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:05<00:00,  0.39it/s]
# Epoch 28: 100%|██████████| 7/7 [00:58<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.34it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.91it/s]
# Epoch 29: 100%|██████████| 7/7 [00:21<00:00,  0.33it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.90it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Epoch 30: 100%|██████████| 7/7 [01:08<00:00,  0.10it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.22it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Epoch 31: 100%|██████████| 7/7 [00:16<00:00,  0.42it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.23it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# Epoch 32: 100%|██████████| 7/7 [00:55<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.30it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# Epoch 33: 100%|██████████| 7/7 [00:17<00:00,  0.41it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.46it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.56it/s]
# Epoch 34: 100%|██████████| 7/7 [00:13<00:00,  0.50it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.78it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Epoch 35: 100%|██████████| 7/7 [00:37<00:00,  0.19it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.52it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.51it/s]
# Epoch 36: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.39it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.64it/s]
# Epoch 37: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.33it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.82it/s]
# Epoch 38: 100%|██████████| 7/7 [00:56<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.11it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.70it/s]
# Epoch 39: 100%|██████████| 7/7 [00:16<00:00,  0.43it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.18it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Epoch 40: 100%|██████████| 7/7 [00:48<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.81it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:06<00:00,  0.33it/s]
# Epoch 41: 100%|██████████| 7/7 [00:25<00:00,  0.28it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.24it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.94it/s]
# Epoch 42: 100%|██████████| 7/7 [00:58<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.12it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# Epoch 43: 100%|██████████| 7/7 [00:16<00:00,  0.43it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.93it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Epoch 44: 100%|██████████| 7/7 [00:47<00:00,  0.15it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.05it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  1.00it/s]
# Epoch 45: 100%|██████████| 7/7 [00:14<00:00,  0.47it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.48it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.71it/s]
# Epoch 46: 100%|██████████| 7/7 [00:24<00:00,  0.28it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.69it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.46it/s]
# Epoch 47: 100%|██████████| 7/7 [00:34<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.29it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.83it/s]
# Epoch 48: 100%|██████████| 7/7 [00:12<00:00,  0.56it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.37it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.81it/s]
# Epoch 49: 100%|██████████| 7/7 [00:47<00:00,  0.15it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.44it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:06<00:00,  0.32it/s]
# Epoch 49: 100%|██████████| 7/7 [00:56<00:00,  0.12it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|██████████| 7/7 [00:56<00:00,  0.12it/s, v_num=0]
#     agg disc  auc_test  silhouette  davies_bouldin
# 0  last  dot  0.888241    0.211006        1.585368
# 1  last  mlp  0.881507    0.388994        0.810540
# 2  attn  dot  0.903780    0.435639        0.779855
# 3  attn  mlp  0.861472    0.528751        0.588269

# %% [markdown]
# Przeprowadzone eksperymenty pokazują, że wybór metody agregacji ma istotny wpływ na jakość uzyskiwanych reprezentacji. Agregacja wykorzystująca mechanizm uwagi osiągała lepsze rezultaty niż wykorzystanie ostatniego stanu ukrytego, co sugeruje skuteczniejsze wykorzystanie informacji zawartych w całej sekwencji. Różnice pomiędzy zastosowanymi dyskryminatorami były mniejsze, jednak najlepsze wyniki uzyskano dla konfiguracji wykorzystujących attention. Można zatem stwierdzić, że mechanizm uwagi pozytywnie wpływa na jakość reprezentacji uczonych przez model TNC.

# %% [markdown]
# ## Zadanie 2.6. Badanie hiperparametrów metody TNC (1.5 pkt)
# Korzystając z podanych funkcji `train()` oraz `evaluate_classification_clustering()` zbadaj następujące hiperparametry:
# - `window_size` (zbadaj co najmniej 3 wartości)
# - `w` (zbadaj co najmniej 3 wartości)
#
# Jeśli uczenie modelu będzie zbyt czasochłonne można zredukować liczbę epok. Każdy z parametrów można zbadać osobno - nie ma potrzeby przeglądania ich przekroju. Analizy powinny być prowadzone na podstawie metryk: AUC (zbiór testowy) oraz metryki klasteryzacji (Silhouette oraz Davies-Bouldin). Utwórz tabelki, które podsumują wyniki eksperymentów. Skomentuj wyniki

# %%
import pandas as pd

base_params = default_hparams.copy()
base_params["agg"] = "attn"
base_params["discriminator"] = "dot"
base_params["num_epochs"] = 25

experiments = []

# Badanie window_size
for window_size in [30, 50, 80]:
    params = base_params.copy()
    params["window_size"] = window_size
    params["name"] = f"window_{window_size}"

    print("\n" + "=" * 60)
    print(f"Badanie window_size = {window_size}")
    print("=" * 60)

    train(params)
    metrics = evaluate_classification_clustering(params["name"])

    experiments.append({
        "badany_parametr": "window_size",
        "wartosc": window_size,
        "auc_test": metrics["auc"]["test"],
        "silhouette": metrics["cluster"]["silhouette"],
        "davies_bouldin": metrics["cluster"]["davies_bouldin"],
    })


# Badanie w
for w in [0.01, 0.05, 0.1]:
    params = base_params.copy()
    params["w"] = w
    params["name"] = f"w_{w}"

    print("\n" + "=" * 60)
    print(f"Badanie w = {w}")
    print("=" * 60)

    train(params)
    metrics = evaluate_classification_clustering(params["name"])

    experiments.append({
        "badany_parametr": "w",
        "wartosc": w,
        "auc_test": metrics["auc"]["test"],
        "silhouette": metrics["cluster"]["silhouette"],
        "davies_bouldin": metrics["cluster"]["davies_bouldin"],
    })

hyperparams_df = pd.DataFrame(experiments)
hyperparams_df
# Out:
# Seed set to 42
# ============================================================
# Badanie window_size = 30
# ============================================================
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 225 K  | train | 0
# 1 | _loss_fn | TNCLossFunction | 0      | train | 0
# -------------------------------------------------------------
# 225 K     Trainable params
# 0         Non-trainable params
# 225 K     Total params
# 0.903     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 7/7 [00:35<00:00,  0.20it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.42it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.78it/s]
# Epoch 1: 100%|██████████| 7/7 [00:15<00:00,  0.47it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.06it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.60it/s]
# Epoch 2: 100%|██████████| 7/7 [00:09<00:00,  0.72it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.82it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.01it/s]
# Epoch 3: 100%|██████████| 7/7 [00:13<00:00,  0.51it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.85it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.88it/s]
# Epoch 4: 100%|██████████| 7/7 [00:38<00:00,  0.18it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.81it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.63it/s]
# Epoch 5: 100%|██████████| 7/7 [00:22<00:00,  0.31it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.20it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.80it/s]
# Epoch 6: 100%|██████████| 7/7 [00:09<00:00,  0.75it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.51it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.23it/s]
# Epoch 7: 100%|██████████| 7/7 [00:11<00:00,  0.60it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.26it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.47it/s]
# Epoch 8: 100%|██████████| 7/7 [00:43<00:00,  0.16it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.56it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.94it/s]
# Epoch 9: 100%|██████████| 7/7 [00:33<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.24it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.11it/s]
# Epoch 10: 100%|██████████| 7/7 [00:13<00:00,  0.51it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.17it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Epoch 11: 100%|██████████| 7/7 [00:52<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:09<00:09,  0.10it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:11<00:00,  0.17it/s]
# Epoch 12: 100%|██████████| 7/7 [00:22<00:00,  0.31it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.25it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.95it/s]
# Epoch 13: 100%|██████████| 7/7 [00:09<00:00,  0.73it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.87it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.62it/s]
# Epoch 14: 100%|██████████| 7/7 [00:13<00:00,  0.53it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.91it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.81it/s]
# Epoch 15: 100%|██████████| 7/7 [00:29<00:00,  0.24it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.30it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.69it/s]
# Epoch 16: 100%|██████████| 7/7 [00:23<00:00,  0.30it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.36it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.30it/s]
# Epoch 17: 100%|██████████| 7/7 [00:09<00:00,  0.75it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  4.35it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.77it/s]
# Epoch 18: 100%|██████████| 7/7 [00:10<00:00,  0.69it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.79it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.12it/s]
# Epoch 19: 100%|██████████| 7/7 [00:16<00:00,  0.42it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.91it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.79it/s]
# Epoch 20: 100%|██████████| 7/7 [00:31<00:00,  0.22it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.88it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.37it/s]
# Epoch 21: 100%|██████████| 7/7 [00:12<00:00,  0.57it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  3.35it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.61it/s]
# Epoch 22: 100%|██████████| 7/7 [00:10<00:00,  0.68it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.51it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.59it/s]
# Epoch 23: 100%|██████████| 7/7 [00:16<00:00,  0.42it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.51it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:05<00:00,  0.35it/s]
# Epoch 24: 100%|██████████| 7/7 [01:02<00:00,  0.11it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.39it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.42it/s]
# Epoch 24: 100%|██████████| 7/7 [01:04<00:00,  0.11it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 7/7 [01:04<00:00,  0.11it/s, v_num=0]
# Seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ============================================================
# Badanie window_size = 50
# ============================================================
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 225 K  | train | 0
# 1 | _loss_fn | TNCLossFunction | 0      | train | 0
# -------------------------------------------------------------
# 225 K     Trainable params
# 0         Non-trainable params
# 225 K     Total params
# 0.903     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 7/7 [00:21<00:00,  0.32it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.28it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.82it/s]
# Epoch 1: 100%|██████████| 7/7 [01:19<00:00,  0.09it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Epoch 2: 100%|██████████| 7/7 [00:44<00:00,  0.16it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:04<00:04,  0.24it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:08<00:00,  0.23it/s]
# Epoch 3: 100%|██████████| 7/7 [00:33<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.47it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.58it/s]
# Epoch 4: 100%|██████████| 7/7 [00:14<00:00,  0.49it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.33it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.92it/s]
# Epoch 5: 100%|██████████| 7/7 [00:46<00:00,  0.15it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.73it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.55it/s]
# Epoch 6: 100%|██████████| 7/7 [00:26<00:00,  0.27it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.46it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.02it/s]
# Epoch 7: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.76it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Epoch 8: 100%|██████████| 7/7 [00:46<00:00,  0.15it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:04<00:04,  0.25it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:07<00:00,  0.26it/s]
# Epoch 9: 100%|██████████| 7/7 [00:18<00:00,  0.37it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.93it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Epoch 10: 100%|██████████| 7/7 [00:31<00:00,  0.22it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:05<00:05,  0.18it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:08<00:00,  0.23it/s]
# Epoch 11: 100%|██████████| 7/7 [00:41<00:00,  0.17it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.76it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.39it/s]
# Epoch 12: 100%|██████████| 7/7 [00:26<00:00,  0.27it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.47it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.46it/s]
# Epoch 13: 100%|██████████| 7/7 [00:45<00:00,  0.15it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.35it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
# Epoch 14: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.99it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.63it/s]
# Epoch 15: 100%|██████████| 7/7 [00:13<00:00,  0.53it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.60it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.61it/s]
# Epoch 16: 100%|██████████| 7/7 [00:28<00:00,  0.25it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.67it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:06<00:00,  0.32it/s]
# Epoch 17: 100%|██████████| 7/7 [00:53<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.99it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.35it/s]
# Epoch 18: 100%|██████████| 7/7 [00:13<00:00,  0.52it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.21it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.96it/s]
# Epoch 19: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.84it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.65it/s]
# Epoch 20: 100%|██████████| 7/7 [01:07<00:00,  0.10it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.21it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
# Epoch 21: 100%|██████████| 7/7 [00:17<00:00,  0.41it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.06it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.41it/s]
# Epoch 22: 100%|██████████| 7/7 [00:22<00:00,  0.30it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.63it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.49it/s]
# Epoch 23: 100%|██████████| 7/7 [00:57<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.32it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Epoch 24: 100%|██████████| 7/7 [00:16<00:00,  0.42it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.92it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
# Epoch 24: 100%|██████████| 7/7 [00:19<00:00,  0.37it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 7/7 [00:19<00:00,  0.36it/s, v_num=0]
# Seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ============================================================
# Badanie window_size = 80
# ============================================================
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 225 K  | train | 0
# 1 | _loss_fn | TNCLossFunction | 0      | train | 0
# -------------------------------------------------------------
# 225 K     Trainable params
# 0         Non-trainable params
# 225 K     Total params
# 0.903     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 7/7 [01:19<00:00,  0.09it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.57it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Epoch 1: 100%|██████████| 7/7 [00:25<00:00,  0.28it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.43it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Epoch 2: 100%|██████████| 7/7 [01:08<00:00,  0.10it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.28it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.89it/s]
# Epoch 3: 100%|██████████| 7/7 [00:40<00:00,  0.17it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.37it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:06<00:00,  0.30it/s]
# Epoch 4: 100%|██████████| 7/7 [00:55<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.87it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.67it/s]
# Epoch 5: 100%|██████████| 7/7 [01:21<00:00,  0.09it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.91it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.84it/s]
# Epoch 6: 100%|██████████| 7/7 [00:32<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.07it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.74it/s]
# Epoch 7: 100%|██████████| 7/7 [01:10<00:00,  0.10it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.43it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# Epoch 8: 100%|██████████| 7/7 [00:32<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.51it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:05<00:00,  0.39it/s]
# Epoch 9: 100%|██████████| 7/7 [00:48<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.53it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.99it/s]
# Epoch 10: 100%|██████████| 7/7 [01:00<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.48it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:05<00:00,  0.34it/s]
# Epoch 11: 100%|██████████| 7/7 [00:51<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.81it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.73it/s]
# Epoch 12: 100%|██████████| 7/7 [01:27<00:00,  0.08it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.89it/s]
# Epoch 13: 100%|██████████| 7/7 [01:05<00:00,  0.11it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:03<00:03,  0.26it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:10<00:00,  0.19it/s]
# Epoch 14: 100%|██████████| 7/7 [00:33<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.93it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.54it/s]
# Epoch 15: 100%|██████████| 7/7 [00:55<00:00,  0.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.46it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Epoch 16: 100%|██████████| 7/7 [00:24<00:00,  0.28it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.29it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.96it/s]
# Epoch 17: 100%|██████████| 7/7 [01:14<00:00,  0.09it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.81it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.70it/s]
# Epoch 18: 100%|██████████| 7/7 [01:03<00:00,  0.11it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:04<00:04,  0.25it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:10<00:00,  0.18it/s]
# Epoch 19: 100%|██████████| 7/7 [00:48<00:00,  0.15it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.94it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.70it/s]
# Epoch 20: 100%|██████████| 7/7 [01:05<00:00,  0.11it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.28it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# Epoch 21: 100%|██████████| 7/7 [00:28<00:00,  0.25it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.20it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.78it/s]
# Epoch 22: 100%|██████████| 7/7 [00:57<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.22it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.94it/s]
# Epoch 23: 100%|██████████| 7/7 [00:24<00:00,  0.29it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.51it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Epoch 24: 100%|██████████| 7/7 [01:09<00:00,  0.10it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.38it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.44it/s]
# Epoch 24: 100%|██████████| 7/7 [01:18<00:00,  0.09it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 7/7 [01:18<00:00,  0.09it/s, v_num=0]
# Seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ============================================================
# Badanie w = 0.01
# ============================================================
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 225 K  | train | 0
# 1 | _loss_fn | TNCLossFunction | 0      | train | 0
# -------------------------------------------------------------
# 225 K     Trainable params
# 0         Non-trainable params
# 225 K     Total params
# 0.903     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 7/7 [00:18<00:00,  0.38it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.67it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.38it/s]
# Epoch 1: 100%|██████████| 7/7 [00:21<00:00,  0.32it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.83it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.77it/s]
# Epoch 2: 100%|██████████| 7/7 [00:50<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.53it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# Epoch 3: 100%|██████████| 7/7 [00:19<00:00,  0.36it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.34it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.02it/s]
# Epoch 4: 100%|██████████| 7/7 [00:12<00:00,  0.58it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.96it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Epoch 5: 100%|██████████| 7/7 [00:25<00:00,  0.28it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:03<00:03,  0.29it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:07<00:00,  0.27it/s]
# Epoch 6: 100%|██████████| 7/7 [00:36<00:00,  0.19it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.57it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.49it/s]
# Epoch 7: 100%|██████████| 7/7 [00:12<00:00,  0.55it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.31it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.93it/s]
# Epoch 8: 100%|██████████| 7/7 [00:13<00:00,  0.52it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.33it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.58it/s]
# Epoch 9: 100%|██████████| 7/7 [00:23<00:00,  0.30it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.19it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.79it/s]
# Epoch 10: 100%|██████████| 7/7 [00:29<00:00,  0.24it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.28it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# Epoch 11: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.86it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.84it/s]
# Epoch 12: 100%|██████████| 7/7 [00:36<00:00,  0.19it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.68it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.47it/s]
# Epoch 13: 100%|██████████| 7/7 [00:28<00:00,  0.25it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.30it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.71it/s]
# Epoch 14: 100%|██████████| 7/7 [00:14<00:00,  0.47it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.93it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.58it/s]
# Epoch 15: 100%|██████████| 7/7 [00:35<00:00,  0.20it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:06<00:06,  0.16it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:10<00:00,  0.20it/s]
# Epoch 16: 100%|██████████| 7/7 [00:38<00:00,  0.18it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.30it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.65it/s]
# Epoch 17: 100%|██████████| 7/7 [00:12<00:00,  0.56it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.35it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.08it/s]
# Epoch 18: 100%|██████████| 7/7 [00:16<00:00,  0.43it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.15it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Epoch 19: 100%|██████████| 7/7 [00:24<00:00,  0.29it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:02<00:02,  0.38it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:05<00:00,  0.38it/s]
# Epoch 20: 100%|██████████| 7/7 [00:26<00:00,  0.26it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.41it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.90it/s]
# Epoch 21: 100%|██████████| 7/7 [00:12<00:00,  0.56it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.75it/s]
# Epoch 22: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.58it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.83it/s]
# Epoch 23: 100%|██████████| 7/7 [00:24<00:00,  0.28it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.56it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.42it/s]
# Epoch 24: 100%|██████████| 7/7 [00:32<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.54it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.55it/s]
# Epoch 24: 100%|██████████| 7/7 [00:34<00:00,  0.20it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 7/7 [00:34<00:00,  0.20it/s, v_num=0]
# Seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 225 K  | train | 0
# 1 | _loss_fn | TNCLossFunction | 0      | train | 0
# -------------------------------------------------------------
# 225 K     Trainable params
# 0         Non-trainable params
# 225 K     Total params
# 0.903     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# ============================================================
# Badanie w = 0.05
# ============================================================
# Epoch 0: 100%|██████████| 7/7 [00:15<00:00,  0.46it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.02it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.42it/s]
# Epoch 1: 100%|██████████| 7/7 [00:25<00:00,  0.28it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:03<00:03,  0.25it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:07<00:00,  0.25it/s]
# Epoch 2: 100%|██████████| 7/7 [00:33<00:00,  0.21it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.89it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
# Epoch 3: 100%|██████████| 7/7 [00:17<00:00,  0.40it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.00it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.73it/s]
# Epoch 4: 100%|██████████| 7/7 [00:12<00:00,  0.55it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.49it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.82it/s]
# Epoch 5: 100%|██████████| 7/7 [00:18<00:00,  0.38it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.87it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.49it/s]
# Epoch 6: 100%|██████████| 7/7 [00:50<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.26it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
# Epoch 7: 100%|██████████| 7/7 [00:12<00:00,  0.56it/s, v_num=0]
# ...
# Epoch 13: 100%|██████████| 7/7 [00:12<00:00,  0.56it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.47it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.85it/s]
# Epoch 14: 100%|██████████| 7/7 [00:13<00:00,  0.51it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.26it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Epoch 15: 100%|██████████| 7/7 [00:26<00:00,  0.26it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.56it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:06<00:00,  0.31it/s]
# Epoch 16: 100%|██████████| 7/7 [00:37<00:00,  0.18it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.67it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Epoch 17: 100%|██████████| 7/7 [00:17<00:00,  0.41it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.10it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.45it/s]
# Epoch 18: 100%|██████████| 7/7 [00:14<00:00,  0.49it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.44it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.82it/s]
# Epoch 19: 100%|██████████| 7/7 [00:35<00:00,  0.20it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:04<00:04,  0.22it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:05<00:00,  0.35it/s]
# Epoch 20: 100%|██████████| 7/7 [00:22<00:00,  0.32it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.56it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.84it/s]
# Epoch 21: 100%|██████████| 7/7 [00:12<00:00,  0.54it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.33it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.89it/s]
# Epoch 22: 100%|██████████| 7/7 [00:16<00:00,  0.44it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.10it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.94it/s]
# Epoch 23: 100%|██████████| 7/7 [00:42<00:00,  0.17it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.23it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.71it/s]
# Epoch 24: 100%|██████████| 7/7 [00:12<00:00,  0.54it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.16it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.86it/s]
# Epoch 24: 100%|██████████| 7/7 [00:14<00:00,  0.48it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 7/7 [00:14<00:00,  0.47it/s, v_num=0]
# Seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name     | Type            | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0 | encoder  | GRUEncoder      | 225 K  | train | 0
# 1 | _loss_fn | TNCLossFunction | 0      | train | 0
# -------------------------------------------------------------
# 225 K     Trainable params
# 0         Non-trainable params
# 225 K     Total params
# 0.903     Total estimated model params size (MB)
# 9         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# ============================================================
# Badanie w = 0.1
# ============================================================
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# /usr/local/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 7/7 [00:19<00:00,  0.37it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.46it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.83it/s]
# Epoch 1: 100%|██████████| 7/7 [00:59<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.98it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.33it/s]
# Epoch 2: 100%|██████████| 7/7 [00:16<00:00,  0.43it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.11it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.71it/s]
# Epoch 3: 100%|██████████| 7/7 [00:19<00:00,  0.37it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.94it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Epoch 4: 100%|██████████| 7/7 [01:20<00:00,  0.09it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.98it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Epoch 5: 100%|██████████| 7/7 [00:28<00:00,  0.25it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:04<00:04,  0.24it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:08<00:00,  0.24it/s]
# Epoch 6: 100%|██████████| 7/7 [00:51<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.52it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.44it/s]
# Epoch 7: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.06it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.48it/s]
# Epoch 8: 100%|██████████| 7/7 [00:43<00:00,  0.16it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.88it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.66it/s]
# Epoch 9: 100%|██████████| 7/7 [00:22<00:00,  0.31it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.60it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.80it/s]
# Epoch 10: 100%|██████████| 7/7 [00:14<00:00,  0.48it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.48it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
# Epoch 11: 100%|██████████| 7/7 [00:49<00:00,  0.14it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.73it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:06<00:00,  0.31it/s]
# Epoch 12: 100%|██████████| 7/7 [00:24<00:00,  0.29it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.40it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.86it/s]
# Epoch 13: 100%|██████████| 7/7 [00:27<00:00,  0.25it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.81it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:04<00:00,  0.46it/s]
# Epoch 14: 100%|██████████| 7/7 [01:05<00:00,  0.11it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.03it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.79it/s]
# Epoch 15: 100%|██████████| 7/7 [00:20<00:00,  0.34it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.04it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:02<00:00,  0.74it/s]
# Epoch 16: 100%|██████████| 7/7 [01:00<00:00,  0.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.29it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
# Epoch 17: 100%|██████████| 7/7 [00:15<00:00,  0.46it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.08it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.90it/s]
# Epoch 18: 100%|██████████| 7/7 [00:14<00:00,  0.48it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.36it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.81it/s]
# Epoch 19: 100%|██████████| 7/7 [00:24<00:00,  0.28it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:01<00:01,  0.56it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:03<00:00,  0.53it/s]
# Epoch 20: 100%|██████████| 7/7 [00:45<00:00,  0.15it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.66it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.42it/s]
# Epoch 21: 100%|██████████| 7/7 [00:15<00:00,  0.45it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  2.36it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.99it/s]
# Epoch 22: 100%|██████████| 7/7 [00:16<00:00,  0.43it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.36it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.21it/s]
# Epoch 23: 100%|██████████| 7/7 [00:39<00:00,  0.18it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:04<00:04,  0.25it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:09<00:00,  0.22it/s]
# Epoch 24: 100%|██████████| 7/7 [00:26<00:00,  0.27it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  1.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:01<00:00,  1.38it/s]
# Epoch 24: 100%|██████████| 7/7 [00:28<00:00,  0.24it/s, v_num=0]
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 7/7 [00:28<00:00,  0.24it/s, v_num=0]
#   badany_parametr  wartosc  auc_test  silhouette  davies_bouldin
# 0     window_size    30.00  0.878596    0.379093        0.872597
# 1     window_size    50.00  0.900933    0.438139        0.784249
# 2     window_size    80.00  0.881708    0.443378        0.775297
# 3               w     0.01  0.901953    0.413701        0.881606
# 4               w     0.05  0.900933    0.438139        0.784249
# 5               w     0.10  0.901527    0.433830        0.810835

# %% [markdown]
# Przeprowadzone eksperymenty pokazują, że rozmiar okna czasowego ma zauważalny wpływ na jakość reprezentacji uczonych przez model TNC. Zbyt małe okno może nie zawierać wystarczającej ilości informacji o dynamice procesu, natomiast zbyt duże może obejmować fragmenty sygnału o bardziej zróżnicowanym charakterze. Najlepsze rezultaty uzyskano dla wartości pośredniej, co sugeruje istnienie kompromisu pomiędzy ilością dostępnego kontekstu czasowego a zdolnością modelu do wyodrębniania istotnych cech. W przypadku parametru $w$ wpływ na wyniki był znacznie mniejszy. Otrzymane rezultaty były zbliżone dla wszystkich analizowanych wartości, co wskazuje, że model jest stosunkowo odporny na umiarkowane zmiany tego hiperparametru. Można zatem stwierdzić, że w badanym zakresie większe znaczenie dla jakości reprezentacji miał dobór rozmiaru okna czasowego niż dokładna wartość parametru $w$.
